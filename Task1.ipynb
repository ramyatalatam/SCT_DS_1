# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("insurance.csv")

print(df[['age', 'sex']].head())
# Out:
#    age     sex
# 0   19  female
# 1   18    male
# 2   28    male
# 3   33    male
# 4   32    male

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['age'], bins=10, kde=True, color='skyblue')
plt.title('Distribution of Age - Medical Cost Dataset')
plt.xlabel('Age')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='sex', data=df, hue='sex', palette='pastel', legend=False)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.grid(axis='y')
plt.show()
